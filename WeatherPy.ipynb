# %%
print('EF')
# Out:
# EF

# %%
from citipy import citipy
import datetime
import pandas as pd
from scipy import stats
import json
import requests
import random
import matplotlib.pyplot as plt

# %%
API_KEY = "fa87ebc6ce0f0896f3d12c6bcab56d4f"
longitude_min = -180
longitude_max = 180
# lattitude: 180 total degrees. requirements: min 500 cities. 
# Look at a world map with lattitude lines, it is clear to see that nothing besides Antarctica, which is unhinhabited,
# resides below -60 degrees lattitude. I gave similar consideration to the area in the world above the 80 degree lattitude line.
# Thus, I will leave out lat coordinates that are <= -60 and >= 80
lattitude_min = -60
lattitude_max = 80
# This leaves me with 140 degrees of lattitude to work with. I will get random numbers in ranges of 5 lattitude degrees. 
# 140 / 5 = 28 - I will have 28 lattitude regions in which to find random coordinates. Minimum Sample n of 500 / 28 = ~18 
# coordinate points for each region, I will get 20 random coorediinates from each lattitude region that will
# translate to an accurate representation of cities across the globe so my analysis of the weather relationships can be trustworthy
lat_lng_coords = []
for i in range(20):
    lat = random.uniform(-60, -55)
    lng = random.uniform(longitude_min, longitude_max)
    lat_lng_coords.append([lat, lng])
for i in range(20):
    lat = random.uniform(-55, -50)
    lng = random.uniform(longitude_min, longitude_max)
    lat_lng_coords.append([lat, lng])
for i in range(20):
    lat = random.uniform(-50, -45)
    lng = random.uniform(longitude_min, longitude_max)
    lat_lng_coords.append([lat, lng])
for i in range(20):
    lat = random.uniform(-45, -40)
    lng = random.uniform(longitude_min, longitude_max)
    lat_lng_coords.append([lat, lng])
for i in range(20):
    lat = random.uniform(-40, -35)
    lng = random.uniform(longitude_min, longitude_max)
    lat_lng_coords.append([lat, lng])
for i in range(20):
    lat = random.uniform(-35, -30)
    lng = random.uniform(longitude_min, longitude_max)
    lat_lng_coords.append([lat, lng])
for i in range(20):
    lat = random.uniform(-30, -25)
    lng = random.uniform(longitude_min, longitude_max)
    lat_lng_coords.append([lat, lng])
for i in range(20):
    lat = random.uniform(-25, -20)
    lng = random.uniform(longitude_min, longitude_max)
    lat_lng_coords.append([lat, lng])
for i in range(20):
    lat = random.uniform(-20, -15)
    lng = random.uniform(longitude_min, longitude_max)
    lat_lng_coords.append([lat, lng])
for i in range(20):
    lat = random.uniform(-15, -10)
    lng = random.uniform(longitude_min, longitude_max)
    lat_lng_coords.append([lat, lng])
for i in range(20):
    lat = random.uniform(-10, -5)
    lng = random.uniform(longitude_min, longitude_max)
    lat_lng_coords.append([lat, lng])
for i in range(20):
    lat = random.uniform(-5, 0)
    lng = random.uniform(longitude_min, longitude_max)
    lat_lng_coords.append([lat, lng])
for i in range(20):
    lat = random.uniform(0, 5)
    lng = random.uniform(longitude_min, longitude_max)
    lat_lng_coords.append([lat, lng])
for i in range(20):
    lat = random.uniform(5, 10)
    lng = random.uniform(longitude_min, longitude_max)
    lat_lng_coords.append([lat, lng])
for i in range(20):
    lat = random.uniform(10, 15)
    lng = random.uniform(longitude_min, longitude_max)
    lat_lng_coords.append([lat, lng])
for i in range(20):
    lat = random.uniform(15, 20)
    lng = random.uniform(longitude_min, longitude_max)
    lat_lng_coords.append([lat, lng])
for i in range(20):
    lat = random.uniform(20, 25)
    lng = random.uniform(longitude_min, longitude_max)
    lat_lng_coords.append([lat, lng])
for i in range(20):
    lat = random.uniform(25, 30)
    lng = random.uniform(longitude_min, longitude_max)
    lat_lng_coords.append([lat, lng])
for i in range(20):
    lat = random.uniform(30, 35)
    lng = random.uniform(longitude_min, longitude_max)
    lat_lng_coords.append([lat, lng])
for i in range(20):
    lat = random.uniform(35, 40)
    lng = random.uniform(longitude_min, longitude_max)
    lat_lng_coords.append([lat, lng])
for i in range(20):
    lat = random.uniform(40, 45)
    lng = random.uniform(longitude_min, longitude_max)
    lat_lng_coords.append([lat, lng])
for i in range(20):
    lat = random.uniform(45, 50)
    lng = random.uniform(longitude_min, longitude_max)
    lat_lng_coords.append([lat, lng])
for i in range(20):
    lat = random.uniform(50, 55)
    lng = random.uniform(longitude_min, longitude_max)
    lat_lng_coords.append([lat, lng])
for i in range(20):
    lat = random.uniform(55, 60)
    lng = random.uniform(longitude_min, longitude_max)
    lat_lng_coords.append([lat, lng])
for i in range(20):
    lat = random.uniform(60, 65)
    lng = random.uniform(longitude_min, longitude_max)
    lat_lng_coords.append([lat, lng])
for i in range(20):
    lat = random.uniform(65, 70)
    lng = random.uniform(longitude_min, longitude_max)
    lat_lng_coords.append([lat, lng])
for i in range(20):
    lat = random.uniform(70, 75)
    lng = random.uniform(longitude_min, longitude_max)
    lat_lng_coords.append([lat, lng])
for i in range(20):
    lat = random.uniform(75, 80)
    lng = random.uniform(longitude_min, longitude_max)
    lat_lng_coords.append([lat, lng])

# %%
# Use coordinates to get city name and country code
city_country_lst = []
for i in lat_lng_coords:
    nearest = citipy.nearest_city(i[0], i[1])
    city = nearest.city_name
    country = nearest.country_code
    city_country_lst.append([city, country])
len(city_country_lst)
len(lat_lng_coords)
# Out:
# 560

# %%
temp = []
humidity = []
wind_speed = []
cloud_percent = []
# get weather data for each city, country in list
print('kldjfklasjd')
count_errors = 0
# hack to get around looping through city_country_lst and not messing up results by getting rid of index while looping through list you are getting rid of index in
# index_lst = []
final_lat_lng_coords= []
final_city_country_lst = []
for i in enumerate(city_country_lst):
    index = i[0]
    print('idx: ', index)
    city_country = i[1]
    city = city_country[0]
    country = city_country[1]
    response = requests.get(f"http://api.openweathermap.org/data/2.5/weather?q={city},{country}&APPID=fa87ebc6ce0f0896f3d12c6bcab56d4f&units=imperial").json()
    if response['cod'] != 200:
        print(f"{city}, {country} not found. Skipping...")
#         index_lst.append(index)
        continue
#         count_errors += 1
#         del lat_lng_coords[index]
#         del city_country_lst[index]
#         continue
    print(f"Processing record {index} | {city}, {country}")
    final_lat_lng_coords.append(lat_lng_coords[index])
    final_city_country_lst.append(city_country)
    temp.append(response["main"]["temp_max"])
    humidity.append(response["main"]["humidity"])
    wind_speed.append(response["wind"]["speed"])
    cloud_percent.append(response["clouds"]["all"])
print("==========\nData Retrieval Complete\n==========")
print('count errors', count_errors)

# loop through index_list and get rid of indexes in lat_lng_coords and city country list
# Out:
# kldjfklasjd
# idx:  0
# Processing record 0 | punta arenas, cl
# idx:  1
# Processing record 1 | port elizabeth, za
# idx:  2
# Processing record 2 | punta arenas, cl
# idx:  3
# taolanaro, mg not found. Skipping...
# idx:  4
# Processing record 4 | punta arenas, cl
# idx:  5
# Processing record 5 | cape town, za
# idx:  6
# Processing record 6 | tuatapere, nz
# idx:  7
# Processing record 7 | punta arenas, cl
# idx:  8
# Processing record 8 | albany, au
# idx:  9
# Processing record 9 | albany, au
# idx:  10
# Processing record 10 | new norfolk, au
# idx:  11
# Processing record 11 | busselton, au
# idx:  12
# Processing record 12 | cidreira, br
# idx:  13
# Processing record 13 | mar del plata, ar
# idx:  14
# Processing record 14 | busselton, au
# idx:  15
# Processing record 15 | albany, au
# idx:  16
# Processing record 16 | busselton, au
# idx:  17
# Processing record 17 | kruisfontein, za
# idx:  18
# Processing record 18 | avarua, ck
# idx:  19
# Processing record 19 | albany, au
# idx:  20
# Processing record 20 | castro, cl
# idx:  21
# Processing record 21 | punta arenas, cl
# idx:  22
# Processing record 22 | busselton, au
# idx:  23
# Processing record 23 | new norfolk, au
# idx:  24
# Processing record 24 | busselton, au
# idx:  25
# Processing record 25 | hobart, au
# idx:  26
# Processing record 26 | cape town, za
# idx:  27
# Processing record 27 | bluff, nz
# idx:  28
# Processing record 28 | tuatapere, nz
# idx:  29
# taolanaro, mg not found. Skipping...
# idx:  30
# Processing record 30 | hermanus, za
# idx:  31
# Processing record 31 | cape town, za
# idx:  32
# Processing record 32 | cape town, za
# idx:  33
# Processing record 33 | rio gallegos, ar
# idx:  34
# Processing record 34 | albany, au
# idx:  35
# Processing record 35 | port elizabeth, za
# idx:  36
# Processing record 36 | new norfolk, au
# idx:  37
# Processing record 37 | avarua, ck
# idx:  38
# Processing record 38 | saint-philippe, re
# idx:  39
# Processing record 39 | busselton, au
# idx:  40
# Processing record 40 | arraial do cabo, br
# idx:  41
# Processing record 41 | rikitea, pf
# idx:  42
# Processing record 42 | albany, au
# idx:  43
# taolanaro, mg not found. Skipping...
# idx:  44
# Processing record 44 | hermanus, za
# idx:  45
# Processing record 45 | souillac, mu
# idx:  46
# Processing record 46 | mar del plata, ar
# idx:  47
# Processing record 47 | tuatapere, nz
# idx:  48
# Processing record 48 | port elizabeth, za
# idx:  49
# Processing record 49 | cape town, za
# idx:  50
# Processing record 50 | tuatapere, nz
# idx:  51
# Processing record 51 | christchurch, nz
# idx:  52
# Processing record 52 | riverton, nz
# idx:  53
# Processing record 53 | port lincoln, au
# idx:  54
# Processing record 54 | rikitea, pf
# idx:  55
# Processing record 55 | castro, cl
# idx:  56
# taolanaro, mg not found. Skipping...
# idx:  57
# Processing record 57 | rikitea, pf
# idx:  58
# Processing record 58 | busselton, au
# idx:  59
# Processing record 59 | rikitea, pf
# idx:  60
# Processing record 60 | amberley, nz
# idx:  61
# Processing record 61 | ancud, cl
# idx:  62
# Processing record 62 | bredasdorp, za
# idx:  63
# Processing record 63 | laguna, br
# idx:  64
# Processing record 64 | mahebourg, mu
# idx:  65
# Processing record 65 | cidreira, br
# idx:  66
# Processing record 66 | busselton, au
# idx:  67
# Processing record 67 | jamestown, sh
# idx:  68
# Processing record 68 | cidreira, br
# idx:  69
# Processing record 69 | arraial do cabo, br
# idx:  70
# Processing record 70 | castro, cl
# idx:  71
# Processing record 71 | waipawa, nz
# idx:  72
# Processing record 72 | east london, za
# idx:  73
# Processing record 73 | busselton, au
# idx:  74
# Processing record 74 | saint-philippe, re
# idx:  75
# Processing record 75 | arraial do cabo, br
# idx:  76
# Processing record 76 | takapau, nz
# idx:  77
# Processing record 77 | castro, cl
# idx:  78
# Processing record 78 | san carlos de bariloche, ar
# idx:  79
# tsihombe, mg not found. Skipping...
# idx:  80
# Processing record 80 | laguna, br
# idx:  81
# Processing record 81 | jamestown, sh
# idx:  82
# Processing record 82 | lebu, cl
# idx:  83
# Processing record 83 | albury, au
# idx:  84
# Processing record 84 | cidreira, br
# idx:  85
# Processing record 85 | lebu, cl
# idx:  86
# Processing record 86 | hermanus, za
# idx:  87
# Processing record 87 | rikitea, pf
# idx:  88
# Processing record 88 | busselton, au
# idx:  89
# Processing record 89 | general roca, ar
# idx:  90
# taolanaro, mg not found. Skipping...
# idx:  91
# mataura, pf not found. Skipping...
# idx:  92
# Processing record 92 | lebu, cl
# idx:  93
# Processing record 93 | sale, au
# idx:  94
# Processing record 94 | arraial do cabo, br
# idx:  95
# Processing record 95 | jamestown, sh
# idx:  96
# Processing record 96 | margate, za
# idx:  97
# Processing record 97 | general roca, ar
# idx:  98
# mataura, pf not found. Skipping...
# idx:  99
# Processing record 99 | nueve de julio, ar
# idx:  100
# Processing record 100 | russell, nz
# idx:  101
# mataura, pf not found. Skipping...
# idx:  102
# Processing record 102 | griffith, au
# idx:  103
# Processing record 103 | lebu, cl
# idx:  104
# Processing record 104 | jamestown, sh
# idx:  105
# Processing record 105 | valparaiso, cl
# idx:  106
# Processing record 106 | ahipara, nz
# idx:  107
# Processing record 107 | coquimbo, cl
# idx:  108
# Processing record 108 | richards bay, za
# idx:  109
# Processing record 109 | lebu, cl
# idx:  110
# Processing record 110 | sao joao da barra, br
# idx:  111
# Processing record 111 | jamestown, sh
# idx:  112
# Processing record 112 | kaeo, nz
# idx:  113
# Processing record 113 | richards bay, za
# idx:  114
# Processing record 114 | ahipara, nz
# idx:  115
# Processing record 115 | port macquarie, au
# idx:  116
# Processing record 116 | carnarvon, au
# idx:  117
# taolanaro, mg not found. Skipping...
# idx:  118
# Processing record 118 | broken hill, au
# idx:  119
# avera, pf not found. Skipping...
# idx:  120
# Processing record 120 | poya, nc
# idx:  121
# Processing record 121 | roma, au
# idx:  122
# Processing record 122 | beloha, mg
# idx:  123
# Processing record 123 | bambous virieux, mu
# idx:  124
# Processing record 124 | arraial do cabo, br
# idx:  125
# Processing record 125 | carnarvon, au
# idx:  126
# Processing record 126 | yulara, au
# idx:  127
# Processing record 127 | rikitea, pf
# idx:  128
# Processing record 128 | poya, nc
# idx:  129
# Processing record 129 | taltal, cl
# idx:  130
# taolanaro, mg not found. Skipping...
# idx:  131
# Processing record 131 | tsabong, bw
# idx:  132
# Processing record 132 | vao, nc
# idx:  133
# Processing record 133 | poya, nc
# idx:  134
# Processing record 134 | rikitea, pf
# idx:  135
# Processing record 135 | luderitz, na
# idx:  136
# Processing record 136 | yulara, au
# idx:  137
# Processing record 137 | yulara, au
# idx:  138
# kawana waters, au not found. Skipping...
# idx:  139
# Processing record 139 | jamestown, sh
# idx:  140
# Processing record 140 | vaini, to
# idx:  141
# mataura, pf not found. Skipping...
# idx:  142
# Processing record 142 | bundaberg, au
# idx:  143
# mataura, pf not found. Skipping...
# idx:  144
# Processing record 144 | jamestown, sh
# idx:  145
# armacao dos buzios, br not found. Skipping...
# idx:  146
# Processing record 146 | rikitea, pf
# idx:  147
# mataura, pf not found. Skipping...
# idx:  148
# Processing record 148 | carnarvon, au
# idx:  149
# Processing record 149 | rikitea, pf
# idx:  150
# Processing record 150 | rikitea, pf
# idx:  151
# Processing record 151 | avarua, ck
# idx:  152
# Processing record 152 | phalaborwa, za
# idx:  153
# Processing record 153 | espirito santo do pinhal, br
# idx:  154
# Processing record 154 | poum, nc
# idx:  155
# Processing record 155 | blackwater, au
# idx:  156
# Processing record 156 | yeppoon, au
# idx:  157
# Processing record 157 | saint-philippe, re
# idx:  158
# Processing record 158 | alice springs, au
# idx:  159
# Processing record 159 | jamestown, sh
# idx:  160
# Processing record 160 | avarua, ck
# idx:  161
# Processing record 161 | oshikango, na
# idx:  162
# Processing record 162 | tsiroanomandidy, mg
# idx:  163
# Processing record 163 | charters towers, au
# idx:  164
# Processing record 164 | rikitea, pf
# idx:  165
# Processing record 165 | pisco, pe
# idx:  166
# Processing record 166 | vaitape, pf
# idx:  167
# Processing record 167 | isangel, vu
# idx:  168
# Processing record 168 | kununurra, au
# idx:  169
# Processing record 169 | namibe, ao
# idx:  170
# Processing record 170 | jamestown, sh
# idx:  171
# Processing record 171 | puerto ayora, ec
# idx:  172
# Processing record 172 | puerto ayora, ec
# idx:  173
# Processing record 173 | puerto ayora, ec
# idx:  174
# Processing record 174 | mount isa, au
# idx:  175
# Processing record 175 | poum, nc
# idx:  176
# Processing record 176 | quatre cocos, mu
# idx:  177
# Processing record 177 | rundu, na
# idx:  178
# Processing record 178 | port hedland, au
# idx:  179
# Processing record 179 | grand gaube, mu
# idx:  180
# Processing record 180 | faanui, pf
# idx:  181
# Processing record 181 | hithadhoo, mv
# idx:  182
# Processing record 182 | hithadhoo, mv
# idx:  183
# Processing record 183 | boyolangu, id
# idx:  184
# Processing record 184 | puerto ayora, ec
# idx:  185
# Processing record 185 | arenapolis, br
# idx:  186
# Processing record 186 | maragogi, br
# idx:  187
# Processing record 187 | rikitea, pf
# idx:  188
# Processing record 188 | luena, ao
# idx:  189
# Processing record 189 | trinidad, bo
# idx:  190
# Processing record 190 | antalaha, mg
# idx:  191
# Processing record 191 | hithadhoo, mv
# idx:  192
# Processing record 192 | alyangula, au
# idx:  193
# Processing record 193 | denpasar, id
# idx:  194
# Processing record 194 | chipata, zm
# idx:  195
# Processing record 195 | hithadhoo, mv
# idx:  196
# Processing record 196 | lichinga, mz
# idx:  197
# Processing record 197 | padang, id
# idx:  198
# Processing record 198 | hithadhoo, mv
# idx:  199
# Processing record 199 | praya, id
# idx:  200
# Processing record 200 | georgetown, sh
# idx:  201
# Processing record 201 | georgetown, sh
# idx:  202
# Processing record 202 | victoria, sc
# idx:  203
# Processing record 203 | honiara, sb
# idx:  204
# Processing record 204 | georgetown, sh
# idx:  205
# lata, sb not found. Skipping...
# idx:  206
# samusu, ws not found. Skipping...
# idx:  207
# Processing record 207 | tual, id
# idx:  208
# Processing record 208 | bengkulu, id
# idx:  209
# Processing record 209 | gamba, ga
# idx:  210
# Processing record 210 | atuona, pf
# idx:  211
# Processing record 211 | santa maria da boa vista, br
# idx:  212
# Processing record 212 | georgetown, sh
# idx:  213
# Processing record 213 | mitsamiouli, km
# idx:  214
# lolua, tv not found. Skipping...
# idx:  215
# Processing record 215 | hithadhoo, mv
# idx:  216
# Processing record 216 | pringsewu, id
# idx:  217
# Processing record 217 | bengkulu, id
# idx:  218
# Processing record 218 | chazuta, pe
# idx:  219
# Processing record 219 | maningrida, au
# idx:  220
# Processing record 220 | touros, br
# idx:  221
# Processing record 221 | faanui, pf
# idx:  222
# Processing record 222 | ndjole, ga
# idx:  223
# Processing record 223 | paciran, id
# idx:  224
# vaitupu, wf not found. Skipping...
# idx:  225
# Processing record 225 | atuona, pf
# idx:  226
# Processing record 226 | puerto ayora, ec
# idx:  227
# Processing record 227 | naberera, tz
# idx:  228
# Processing record 228 | salinas, ec
# idx:  229
# Processing record 229 | victoria, sc
# idx:  230
# Processing record 230 | paragominas, br
# idx:  231
# Processing record 231 | djambala, cg
# idx:  232
# Processing record 232 | padang, id
# idx:  233
# Processing record 233 | atuona, pf
# idx:  234
# Processing record 234 | lorengau, pg
# idx:  235
# Processing record 235 | harper, lr
# idx:  236
# Processing record 236 | itapage, br
# idx:  237
# Processing record 237 | muana, br
# idx:  238
# Processing record 238 | tabou, ci
# idx:  239
# Processing record 239 | atuona, pf
# idx:  240
# Processing record 240 | banda aceh, id
# idx:  241
# saleaula, ws not found. Skipping...
# idx:  242
# Processing record 242 | namatanai, pg
# idx:  243
# Processing record 243 | nanyuki, ke
# idx:  244
# Processing record 244 | lorengau, pg
# idx:  245
# Processing record 245 | atuona, pf
# idx:  246
# Processing record 246 | puerto ayora, ec
# idx:  247
# Processing record 247 | faanui, pf
# idx:  248
# Processing record 248 | camopi, gf
# idx:  249
# Processing record 249 | amapa, br
# idx:  250
# Processing record 250 | kavieng, pg
# idx:  251
# Processing record 251 | kloulklubed, pw
# idx:  252
# Processing record 252 | jardim, br
# idx:  253
# Processing record 253 | harper, lr
# idx:  254
# Processing record 254 | ixtapa, mx
# idx:  255
# Processing record 255 | butaritari, ki
# idx:  256
# saleaula, ws not found. Skipping...
# idx:  257
# Processing record 257 | mapiripan, co
# idx:  258
# Processing record 258 | butembo, cd
# idx:  259
# Processing record 259 | vanimo, pg
# idx:  260
# Processing record 260 | oshogbo, ng
# idx:  261
# Processing record 261 | cabo san lucas, mx
# idx:  262
# Processing record 262 | bandarbeyla, so
# idx:  263
# Processing record 263 | lorengau, pg
# idx:  264
# Processing record 264 | cururupu, br
# idx:  265
# Processing record 265 | atuona, pf
# idx:  266
# tambura, sd not found. Skipping...
# idx:  267
# Processing record 267 | bubaque, gw
# idx:  268
# Processing record 268 | toledo, co
# idx:  269
# Processing record 269 | harer, et
# idx:  270
# Processing record 270 | sao filipe, cv
# idx:  271
# Processing record 271 | pak phanang, th
# idx:  272
# Processing record 272 | bacolod, ph
# idx:  273
# Processing record 273 | butaritari, ki
# idx:  274
# Processing record 274 | marang, my
# idx:  275
# Processing record 275 | mandera, ke
# idx:  276
# Processing record 276 | butaritari, ki
# idx:  277
# Processing record 277 | hilo, us
# idx:  278
# Processing record 278 | cayenne, gf
# idx:  279
# Processing record 279 | zwedru, lr
# idx:  280
# Processing record 280 | gorom-gorom, bf
# idx:  281
# Processing record 281 | korem, et
# idx:  282
# Processing record 282 | hilo, us
# idx:  283
# Processing record 283 | hilo, us
# idx:  284
# Processing record 284 | sinnamary, gf
# idx:  285
# Processing record 285 | butaritari, ki
# idx:  286
# Processing record 286 | limon, cr
# idx:  287
# Processing record 287 | kapaa, us
# idx:  288
# Processing record 288 | hilo, us
# idx:  289
# Processing record 289 | sao filipe, cv
# idx:  290
# Processing record 290 | dawei, mm
# idx:  291
# Processing record 291 | port blair, in
# idx:  292
# Processing record 292 | lorengau, pg
# idx:  293
# Processing record 293 | dakar, sn
# idx:  294
# Processing record 294 | port blair, in
# idx:  295
# Processing record 295 | itarema, br
# idx:  296
# Processing record 296 | cayenne, gf
# idx:  297
# Processing record 297 | hilo, us
# idx:  298
# huazolotitlan, mx not found. Skipping...
# idx:  299
# Processing record 299 | duku, ng
# idx:  300
# codrington, ag not found. Skipping...
# idx:  301
# Processing record 301 | porto novo, cv
# idx:  302
# airai, pw not found. Skipping...
# idx:  303
# Processing record 303 | petatlan, mx
# idx:  304
# Processing record 304 | kapaa, us
# idx:  305
# Processing record 305 | morant bay, jm
# idx:  306
# Processing record 306 | mao, td
# idx:  307
# airai, pw not found. Skipping...
# idx:  308
# Processing record 308 | pyinmana, mm
# idx:  309
# Processing record 309 | cabo san lucas, mx
# idx:  310
# Processing record 310 | santa maria, cv
# idx:  311
# airai, pw not found. Skipping...
# idx:  312
# faya, td not found. Skipping...
# idx:  313
# tawkar, sd not found. Skipping...
# idx:  314
# Processing record 314 | sinnamary, gf
# idx:  315
# Processing record 315 | kavieng, pg
# idx:  316
# Processing record 316 | bombay, in
# idx:  317
# Processing record 317 | kapaa, us
# idx:  318
# Processing record 318 | tomatlan, mx
# idx:  319
# Processing record 319 | cayenne, gf
# idx:  320
# Processing record 320 | arlit, ne
# idx:  321
# Processing record 321 | nouadhibou, mr
# idx:  322
# Processing record 322 | road town, vg
# idx:  323
# Processing record 323 | butaritari, ki
# idx:  324
# Processing record 324 | butaritari, ki
# idx:  325
# Processing record 325 | mushabani, in
# idx:  326
# Processing record 326 | bathsheba, bb
# idx:  327
# Processing record 327 | monywa, mm
# idx:  328
# Processing record 328 | kapaa, us
# idx:  329
# Processing record 329 | nishihara, jp
# idx:  330
# Processing record 330 | barghat, in
# idx:  331
# Processing record 331 | bilma, ne
# idx:  332
# Processing record 332 | haimen, cn
# idx:  333
# Processing record 333 | constitucion, mx
# idx:  334
# Processing record 334 | abu dhabi, ae
# idx:  335
# Processing record 335 | makaha, us
# idx:  336
# Processing record 336 | nuevo progreso, mx
# idx:  337
# Processing record 337 | banswara, in
# idx:  338
# Processing record 338 | bathsheba, bb
# idx:  339
# Processing record 339 | rajur, in
# idx:  340
# Processing record 340 | guerrero negro, mx
# idx:  341
# Processing record 341 | kapaa, us
# idx:  342
# Processing record 342 | katsuura, jp
# idx:  343
# Processing record 343 | cockburn town, bs
# idx:  344
# yaan, cn not found. Skipping...
# idx:  345
# Processing record 345 | hasaki, jp
# idx:  346
# Processing record 346 | adrar, dz
# idx:  347
# Processing record 347 | khairabad, in
# idx:  348
# Processing record 348 | hasaki, jp
# idx:  349
# Processing record 349 | kapaa, us
# idx:  350
# Processing record 350 | gasa, bt
# idx:  351
# Processing record 351 | kahului, us
# idx:  352
# codrington, ag not found. Skipping...
# idx:  353
# Processing record 353 | los llanos de aridane, es
# idx:  354
# Processing record 354 | kapaa, us
# idx:  355
# Processing record 355 | along, in
# idx:  356
# Processing record 356 | half moon bay, us
# idx:  357
# warqla, dz not found. Skipping...
# idx:  358
# Processing record 358 | pacific grove, us
# idx:  359
# codrington, ag not found. Skipping...
# idx:  360
# Processing record 360 | beidao, cn
# idx:  361
# Processing record 361 | katsuura, jp
# idx:  362
# Processing record 362 | kapaa, us
# idx:  363
# Processing record 363 | surt, ly
# idx:  364
# Processing record 364 | shush, ir
# idx:  365
# Processing record 365 | lake havasu city, us
# idx:  366
# Processing record 366 | florence, us
# idx:  367
# Processing record 367 | hasaki, jp
# idx:  368
# Processing record 368 | lexington, us
# idx:  369
# Processing record 369 | clovis, us
# idx:  370
# Processing record 370 | lake city, us
# idx:  371
# Processing record 371 | mount pleasant, us
# idx:  372
# Processing record 372 | ypsonas, cy
# idx:  373
# Processing record 373 | fredericksburg, us
# idx:  374
# sentyabrskiy, ru not found. Skipping...
# idx:  375
# Processing record 375 | teguise, es
# idx:  376
# Processing record 376 | orangeburg, us
# idx:  377
# Processing record 377 | nikolskoye, ru
# idx:  378
# Processing record 378 | lompoc, us
# idx:  379
# Processing record 379 | half moon bay, us
# idx:  380
# Processing record 380 | khoy, ir
# idx:  381
# Processing record 381 | montrose, us
# idx:  382
# Processing record 382 | shelburne, ca
# idx:  383
# Processing record 383 | severo-kurilsk, ru
# idx:  384
# Processing record 384 | tortoli, it
# idx:  385
# Processing record 385 | tithorea, gr
# idx:  386
# Processing record 386 | karaman, tr
# idx:  387
# Processing record 387 | vila franca do campo, pt
# idx:  388
# Processing record 388 | fortuna, us
# idx:  389
# Processing record 389 | calvia, es
# idx:  390
# Processing record 390 | ponta do sol, pt
# idx:  391
# Processing record 391 | camacha, pt
# idx:  392
# Processing record 392 | kamaishi, jp
# idx:  393
# kerki, tm not found. Skipping...
# idx:  394
# Processing record 394 | milharado, pt
# idx:  395
# Processing record 395 | gonbad-e qabus, ir
# idx:  396
# Processing record 396 | torbay, ca
# idx:  397
# Processing record 397 | beysehir, tr
# idx:  398
# Processing record 398 | hengshui, cn
# idx:  399
# Processing record 399 | baiyin, cn
# idx:  400
# Processing record 400 | bethel, us
# idx:  401
# louisbourg, ca not found. Skipping...
# idx:  402
# Processing record 402 | primorsko, bg
# idx:  403
# Processing record 403 | ribeira grande, pt
# idx:  404
# Processing record 404 | lapeer, us
# idx:  405
# Processing record 405 | mitchell, us
# idx:  406
# Processing record 406 | jackson, us
# idx:  407
# dzhusaly, kz not found. Skipping...
# idx:  408
# Processing record 408 | kodiak, us
# idx:  409
# Processing record 409 | shu, kz
# idx:  410
# Processing record 410 | kashi, cn
# idx:  411
# Processing record 411 | nikolskoye, ru
# idx:  412
# Processing record 412 | torbay, ca
# idx:  413
# Processing record 413 | eureka, us
# idx:  414
# Processing record 414 | lagoa, pt
# idx:  415
# Processing record 415 | newport, us
# idx:  416
# Processing record 416 | sitka, us
# idx:  417
# Processing record 417 | konokovo, ru
# idx:  418
# Processing record 418 | miranda de ebro, es
# idx:  419
# Processing record 419 | praia da vitoria, pt
# idx:  420
# Processing record 420 | sitka, us
# idx:  421
# Processing record 421 | nikolskoye, ru
# idx:  422
# Processing record 422 | fort frances, ca
# idx:  423
# Processing record 423 | lagoa, pt
# idx:  424
# Processing record 424 | taber, ca
# idx:  425
# Processing record 425 | primorsko-akhtarsk, ru
# idx:  426
# Processing record 426 | lagoa, pt
# idx:  427
# Processing record 427 | wakkanai, jp
# idx:  428
# Processing record 428 | lagoa, pt
# idx:  429
# Processing record 429 | bethel, us
# idx:  430
# wulanhaote, cn not found. Skipping...
# idx:  431
# Processing record 431 | kodiak, us
# idx:  432
# Processing record 432 | miles city, us
# idx:  433
# Processing record 433 | ribeira grande, pt
# idx:  434
# Processing record 434 | houlton, us
# idx:  435
# Processing record 435 | ketchikan, us
# idx:  436
# Processing record 436 | marfino, ru
# idx:  437
# Processing record 437 | cervo, es
# idx:  438
# Processing record 438 | darhan, mn
# idx:  439
# Processing record 439 | kodiak, us
# idx:  440
# ust-kamchatsk, ru not found. Skipping...
# idx:  441
# longlac, ca not found. Skipping...
# idx:  442
# Processing record 442 | uyskoye, ru
# idx:  443
# Processing record 443 | dingle, ie
# idx:  444
# Processing record 444 | sergeyevka, kz
# idx:  445
# pribelskiy, ru not found. Skipping...
# idx:  446
# Processing record 446 | inzer, ru
# idx:  447
# Processing record 447 | provideniya, ru
# idx:  448
# Processing record 448 | crosby, gb
# idx:  449
# Processing record 449 | vostok, ru
# idx:  450
# Processing record 450 | bagdarin, ru
# idx:  451
# Processing record 451 | worcester, gb
# idx:  452
# Processing record 452 | severo-kurilsk, ru
# idx:  453
# Processing record 453 | shebalino, ru
# idx:  454
# Processing record 454 | chapais, ca
# idx:  455
# Processing record 455 | kodiak, us
# idx:  456
# Processing record 456 | tungor, ru
# idx:  457
# Processing record 457 | wembley, ca
# idx:  458
# Processing record 458 | matagami, ca
# idx:  459
# Processing record 459 | provideniya, ru
# idx:  460
# sedelnikovo, ru not found. Skipping...
# idx:  461
# Processing record 461 | fort nelson, ca
# idx:  462
# Processing record 462 | beringovskiy, ru
# idx:  463
# Processing record 463 | westport, ie
# idx:  464
# chagda, ru not found. Skipping...
# idx:  465
# Processing record 465 | iqaluit, ca
# idx:  466
# Processing record 466 | south shields, gb
# idx:  467
# Processing record 467 | chunskiy, ru
# idx:  468
# attawapiskat, ca not found. Skipping...
# idx:  469
# Processing record 469 | tananger, no
# idx:  470
# Processing record 470 | provideniya, ru
# idx:  471
# Processing record 471 | iqaluit, ca
# idx:  472
# Processing record 472 | provideniya, ru
# idx:  473
# Processing record 473 | bethel, us
# idx:  474
# Processing record 474 | tommot, ru
# idx:  475
# Processing record 475 | esso, ru
# idx:  476
# Processing record 476 | provideniya, ru
# idx:  477
# Processing record 477 | sitka, us
# idx:  478
# Processing record 478 | wick, gb
# idx:  479
# Processing record 479 | iqaluit, ca
# idx:  480
# Processing record 480 | berdigestyakh, ru
# idx:  481
# Processing record 481 | mayo, ca
# idx:  482
# Processing record 482 | igrim, ru
# idx:  483
# attawapiskat, ca not found. Skipping...
# idx:  484
# Processing record 484 | iqaluit, ca
# idx:  485
# Processing record 485 | iqaluit, ca
# idx:  486
# Processing record 486 | thompson, ca
# idx:  487
# Processing record 487 | vaasa, fi
# idx:  488
# Processing record 488 | mayo, ca
# idx:  489
# Processing record 489 | fort nelson, ca
# idx:  490
# Processing record 490 | puksoozero, ru
# idx:  491
# aras, no not found. Skipping...
# idx:  492
# Processing record 492 | tura, ru
# idx:  493
# Processing record 493 | khandyga, ru
# idx:  494
# Processing record 494 | solnechnyy, ru
# idx:  495
# Processing record 495 | novoagansk, ru
# idx:  496
# Processing record 496 | nesbyen, no
# idx:  497
# Processing record 497 | oktyabrskoye, ru
# idx:  498
# Processing record 498 | bethel, us
# idx:  499
# attawapiskat, ca not found. Skipping...
# idx:  500
# Processing record 500 | igarka, ru
# idx:  501
# Processing record 501 | klaksvik, fo
# idx:  502
# Processing record 502 | novyy urengoy, ru
# idx:  503
# Processing record 503 | vestmanna, fo
# idx:  504
# Processing record 504 | zyryanka, ru
# idx:  505
# Processing record 505 | sistranda, no
# idx:  506
# Processing record 506 | leningradskiy, ru
# idx:  507
# karaul, ru not found. Skipping...
# idx:  508
# Processing record 508 | aklavik, ca
# idx:  509
# Processing record 509 | barrow, us
# idx:  510
# Processing record 510 | inuvik, ca
# idx:  511
# Processing record 511 | zhigansk, ru
# idx:  512
# attawapiskat, ca not found. Skipping...
# idx:  513
# Processing record 513 | igarka, ru
# idx:  514
# Processing record 514 | barrow, us
# idx:  515
# Processing record 515 | batagay-alyta, ru
# idx:  516
# Processing record 516 | sistranda, no
# idx:  517
# Processing record 517 | aykhal, ru
# idx:  518
# Processing record 518 | tasiilaq, gl
# idx:  519
# Processing record 519 | naryan-mar, ru
# idx:  520
# Processing record 520 | ostrovnoy, ru
# idx:  521
# Processing record 521 | talnakh, ru
# idx:  522
# Processing record 522 | kayerkan, ru
# idx:  523
# Processing record 523 | barrow, us
# idx:  524
# Processing record 524 | vardo, no
# idx:  525
# Processing record 525 | ust-kuyga, ru
# idx:  526
# Processing record 526 | cherskiy, ru
# idx:  527
# Processing record 527 | nome, us
# idx:  528
# Processing record 528 | yellowknife, ca
# idx:  529
# Processing record 529 | tasiilaq, gl
# idx:  530
# Processing record 530 | clyde river, ca
# idx:  531
# Processing record 531 | sorland, no
# idx:  532
# Processing record 532 | barrow, us
# idx:  533
# Processing record 533 | andenes, no
# idx:  534
# Processing record 534 | chokurdakh, ru
# idx:  535
# Processing record 535 | yellowknife, ca
# idx:  536
# Processing record 536 | klaksvik, fo
# idx:  537
# nizhneyansk, ru not found. Skipping...
# idx:  538
# Processing record 538 | vestmanna, fo
# idx:  539
# Processing record 539 | tasiilaq, gl
# idx:  540
# Processing record 540 | khatanga, ru
# idx:  541
# Processing record 541 | dikson, ru
# idx:  542
# belushya guba, ru not found. Skipping...
# idx:  543
# belushya guba, ru not found. Skipping...
# idx:  544
# Processing record 544 | dikson, ru
# idx:  545
# Processing record 545 | qaanaaq, gl
# idx:  546
# Processing record 546 | thompson, ca
# idx:  547
# Processing record 547 | dikson, ru
# idx:  548
# Processing record 548 | tuktoyaktuk, ca
# idx:  549
# amderma, ru not found. Skipping...
# idx:  550
# Processing record 550 | yellowknife, ca
# idx:  551
# Processing record 551 | barrow, us
# idx:  552
# amderma, ru not found. Skipping...
# idx:  553
# barentsburg, sj not found. Skipping...
# idx:  554
# Processing record 554 | longyearbyen, sj
# idx:  555
# Processing record 555 | saskylakh, ru
# idx:  556
# belushya guba, ru not found. Skipping...
# idx:  557
# Processing record 557 | tuktoyaktuk, ca
# idx:  558
# Processing record 558 | narsaq, gl
# idx:  559
# Processing record 559 | saskylakh, ru
# ==========
# Data Retrieval Complete
# ==========
# count errors 0

# %%
# print('idx list', len(index_lst))
print('final lat lng', len(final_lat_lng_coords))
print('finL city country', len(final_city_country_lst))
print(len(temp), len(humidity))
# print(index_lst)
# for i in index_lst:
#     print(i)
#     lat_lng_coords.pop(i)
#     city_country_lst.pop(i)
# print('final city country lng lat', len(lat_lng_coor))
# Out:
# final lat lng 502
# finL city country 502
# 502 502

# %%
# put lattitude, longitude, city, country into own arrays 
lat = []
lng = []
city_lst = []
country_lst = []
for i in final_lat_lng_coords:
    lat.append(i[0])
    lng.append(i[1])
for i in final_city_country_lst:
    city_lst.append(i[0])
    country_lst.append(i[1])
print(len(lat), len(lng), len(city_lst), len(country_lst))
# Out:
# 502 502 502 502

# %%
city_weather_dct = {
    "lattitude": lat,
    "longitude": lng,
    "city": city_lst,
    "country": country_lst,
    "max_temperature": temp,
    "humidity": humidity,
    "wind_speed": wind_speed,
    "cloud_percentage": cloud_percent
}
for key, val in city_weather_dct.items():
    print(key, 'length:', len(val))
df = pd.DataFrame(city_weather_dct)
df.head()

# lat vs temp
x_vals = df["lattitude"]
y_vals = df["max_temperature"]
plt.scatter(x_vals, y_vals)
plt.xlabel("Lattitude")
plt.ylabel("Temperature")
plt.title("City Lattitude vs Max Temperature 09/30/20")
plt.show()
print("The code for this section scatter-plots Lattitude as the dependent variable (x-axis) and Maximum Temperature as the independent variable (y-axis).")
print("The scatter plot shows that temperatures are reliably colder at the more extreme Lattitudes or closer to the poles. Temperatures near the Lattitude 0, or closer to the center of the earth, are reliably warmer than at geogrpahic points farther away from the center of the earth.")

# Lat vs humidity
y_vals = df["humidity"]
plt.scatter(x_vals, y_vals)
plt.xlabel("Lattitude")
plt.ylabel("Humidity")
plt.title("City Lattitude vs Humidity 09/30/20")
plt.show()
print("The code for this section scatter-plots Lattitude as the dependent variable (x-axis) and Humidity as the independent variable (y-axis).")
print("The scatter plot does not show a reliable relationship")

# Lat vs CLoudiness
y_vals = df["cloud_percentage"]
plt.scatter(x_vals, y_vals)
plt.xlabel("Lattitude")
plt.ylabel("Cloudiness %")
plt.title("City Lattitude vs. Cloudiness 09/30/20")
plt.show()
print("The code for this section scatter-plots Lattitude as the dependent variable (x-axis) and Cloudiness Percentage as the independent variable (y-axis).")
print("The scatter plot does not show a reliable relationship to make any conclusions about the effect of Lattitude on Cloudiness")

# Lat vs Wind Speed
y_vals = df["wind_speed"]
plt.scatter(x_vals, y_vals)
plt.xlabel("Lattitude")
plt.ylabel("Wind Speed")
plt.title("City Lattitude vs. Wind Speed")
plt.show()
print("The code for this section scatter-plots Lattitude as the dependent variable (x-axis) and Wind Speed as the independent variable (y-axis).")
print("You can see a mild negative relationship between higher lattitudes and wind speed")
# Out:
# lattitude length: 502
# longitude length: 502
# city length: 502
# country length: 502
# max_temperature length: 502
# humidity length: 502
# wind_speed length: 502
# cloud_percentage length: 502
# The code for this section scatter-plots Lattitude as the dependent variable (x-axis) and Maximum Temperature as the independent variable (y-axis).
# The scatter plot shows that temperatures are reliably colder at the more extreme Lattitudes or closer to the poles. Temperatures near the Lattitude 0, or closer to the center of the earth, are reliably warmer than at geogrpahic points farther away from the center of the earth.
# The code for this section scatter-plots Lattitude as the dependent variable (x-axis) and Humidity as the independent variable (y-axis).
# The scatter plot does not show a reliable relationship
# The code for this section scatter-plots Lattitude as the dependent variable (x-axis) and Cloudiness Percentage as the independent variable (y-axis).
# The scatter plot does not show a reliable relationship to make any conclusions about the effect of Lattitude on Cloudiness
# The code for this section scatter-plots Lattitude as the dependent variable (x-axis) and Wind Speed as the independent variable (y-axis).
# You can see a mild negative relationship between higher lattitudes and wind speed

# %%
# Lat and Temp Regression

y_vals = df["max_temperature"]

(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_vals, y_vals)


regress_values = x_vals * slope + intercept
print(regress_values)
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
print(line_eq)
plt.scatter(x_vals,y_vals)
plt.plot(x_vals,regress_values,"r-")

plt.xlabel('Latitude')
plt.ylabel('Max Temperature')
plt.annotate(line_eq,(20,15),fontsize=15,color="red")

print(f"The r-value is: {rvalue**2}")

plt.show()
# Out:
# 0      72.920506
# 1      73.205968
# 2      72.841175
# 3      73.301623
# 4      72.984930
#          ...
# 497    53.891000
# 498    53.987432
# 499    54.320035
# 500    54.317118
# 501    54.031281
# Name: lattitude, Length: 502, dtype: float64
# y = -0.14x +65.01
# The r-value is: 0.10375176664883215

# %%
# Lat and Humidity Regression 

y_vals = df["humidity"]
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_vals, y_vals)
regress_values = x_vals * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
print(line_eq)
plt.scatter(x_vals,y_vals)
plt.plot(x_vals,regress_values,"r-")
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.annotate(line_eq,(20,15),fontsize=15,color="red")
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# y = 0.09x +71.34
# The r-value is: 0.03622404614178125

# %%
# Lat and Cloudiness Regression 

y_vals = df["cloud_percentage"]
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_vals, y_vals)
regress_values = x_vals * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
print(line_eq)
plt.scatter(x_vals,y_vals)
plt.plot(x_vals,regress_values,"r-")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness %')
plt.annotate(line_eq,(20,15),fontsize=15,color="red")
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# y = 0.17x +49.44
# The r-value is: 0.0351326257114967

# %%
# Lat and Wind Speed 

y_vals = df["cloud_percentage"]
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_vals, y_vals)
regress_values = x_vals * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
print(line_eq)
plt.scatter(x_vals,y_vals)
plt.plot(x_vals,regress_values,"r-")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness %')
plt.annotate(line_eq,(20,15),fontsize=15,color="red")
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# y = 0.17x +49.44
# The r-value is: 0.0351326257114967

# %%
df.to_csv("WeatherPy_data.csv")
